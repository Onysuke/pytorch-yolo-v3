# %%
import os 
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
path = '/var/docker/data/cow/pics/20171210/2017121017/20171210170005.jpg'
image = Image.open(path)
plt.imshow(image)

# %%
path = '../output/det_20171210170005.jpg'
image = Image.open(path)
plt.imshow(image)

# %%
path = '../output/det_20171210170005.jpg'
image = Image.open(path)
plt.figure(figsize=(16,16))
plt.imshow(image)

# %%
path = '../output/det_20171210170005.jpg'
image = Image.open(path)
plt.figure(figsize=(16,16))
plt.imshow(image)
